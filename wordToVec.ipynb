# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp39-cp39-win_amd64.whl.metadata (8.2 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in d:\nlp\.venv\lib\site-packages (from gensim) (1.13.1)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim)
#   Downloading wrapt-1.17.3-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Downloading gensim-4.3.3-cp39-cp39-win_amd64.whl (24.0 MB)
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/24.0 MB 16.7 MB/s eta 0:00:02
#    ------ --------------------------------- 3.7/24.0 MB 9.1 MB/s eta 0:00:03
#    --------- ------------------------------ 5.5/24.0 MB 9.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.6/24.0 MB 7.9 MB/s eta 0:00:03
#    ------------ --------------------------- 7.6/24.0 MB 7.3 MB/s eta 0:00:03
#    ------------- -------------------------- 8.1/24.0 MB 6.9 MB/s eta 0:00:03
#    -------------- ------------------------- 8.9/24.0 MB 6.1 MB/s eta 0:00:03
#    --------------- ------------------------ 9.4/24.0 MB 5.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 10.0/24.0 MB 5.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 10.5/24.0 MB 5.1 MB/s eta 0:00:03
#    ------------------ --------------------- 11.0/24.0 MB 4.7 MB/s eta 0:00:03
#    ------------------- -------------------- 11.5/24.0 MB 4.5 MB/s eta 0:00:03
#    -------------------- ------------------- 12.1/24.0 MB 4.4 MB/s eta 0:00:03
#    --------------------- ------------------ 12.8/24.0 MB 4.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 13.6/24.0 MB 4.3 MB/s eta 0:00:03
#    ------------------------ --------------- 14.4/24.0 MB 4.2 MB/s eta 0:00:03
#    ------------------------- -------------- 15.5/24.0 MB 4.2 MB/s eta 0:00:03
#    --------------------------- ------------ 16.5/24.0 MB 4.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.8/24.0 MB 4.4 MB/s eta 0:00:02
#    ------------------------------- -------- 18.9/24.0 MB 4.4 MB/s eta 0:00:02
#    ------------------------------- -------- 18.9/24.0 MB 4.4 MB/s eta 0:00:02
#    --------------------------------- ------ 19.9/24.0 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.2/24.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 22.8/24.0 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  23.9/24.0 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 4.4 MB/s  0:00:05
# Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/15.8 MB 7.6 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/15.8 MB 7.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/15.8 MB 7.0 MB/s eta 0:00:02
#    ------------ --------------------------- 5.0/15.8 MB 6.2 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.8 MB 5.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/15.8 MB 5.7 MB/s eta 0:00:02
#    --------------------- ------------------ 8.4/15.8 MB 5.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/15.8 MB 5.6 MB/s eta 0:00:02
#    --------------------------- ------------ 10.7/15.8 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.8 MB 5.6 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.8 MB 5.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.8 MB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/15.8 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.6/15.8 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/15.8 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 3.9 MB/s  0:00:04
# Downloading smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Downloading wrapt-1.17.3-cp39-cp39-win_amd64.whl (38 kB)
# Installing collected packages: wrapt, numpy, smart-open, gensim
#
#    ---------------------------------------- 0/4 [wrapt]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/4 [wrapt]
#     Found existing installation: numpy 2.0.2
#    ---------------------------------------- 0/4 [wrapt]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#     Uninstalling numpy-2.0.2:
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#       Successfully uninstalled numpy-2.0.2
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    -------------------- ------------------- 2/4 [smart-open]
#    -------------------- ------------------- 2/4 [smart-open]
#    -------------------- ------------------- 2/4 [smart-open]
#    -------------------- ------------------- 2/4 [smart-open]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ------------------------------ --------- 3/4 [gensim]
#    ---------------------------------------- 4/4 [gensim]
#
# Successfully installed gensim-4.3.3 numpy-1.26.4 smart-open-7.3.0.post1 wrapt-1.17.3
#   WARNING: Failed to remove contents in a temporary directory 'D:\NLP\.venv\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\NLP\.venv\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('glove-wiki-gigaword-100')
vec_king = wv['king']
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
vec_king
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
#        -0.91627 ,  0.64521 ,  0.73281 , -0.22752 ,  0.30226 ,  0.044801,
#        -0.83741 ,  0.55006 , -0.52506 , -1.7357  ,  0.4751  , -0.70487 ,
#         0.056939, -0.7132  ,  0.089623,  0.41394 , -1.3363  , -0.61915 ,
#        -0.33089 , -0.52881 ,  0.16483 , -0.98878 ], dtype=float32)

# %%
vec_king.shape
# Out:
# (100,)

# %%
wv['cricket']
# Out:
# array([-0.55541  ,  0.45894  ,  0.51851  , -0.045938 , -1.4064   ,
#         0.49701  , -0.085008 ,  0.63442  , -1.7949   , -0.31881  ,
#        -0.13673  , -1.1583   ,  0.45505  ,  0.21464  , -0.21751  ,
#        -0.21984  ,  0.60619  ,  0.55812  , -0.01031  ,  0.66228  ,
#         0.22206  ,  0.25498  ,  0.8452   , -0.72988  ,  0.26195  ,
#         0.26418  ,  0.22577  , -0.051338 ,  0.024459 ,  0.86389  ,
#        -0.35585  ,  0.48662  , -0.49752  , -0.44777  , -0.040533 ,
#        -0.18376  , -1.32     ,  0.54899  , -1.2289   , -0.22673  ,
#        -0.93431  ,  0.78923  ,  0.9565   , -1.3996   ,  1.0314   ,
#         0.39573  ,  0.7956   , -0.27184  ,  0.51776  , -1.0387   ,
#        -0.38121  ,  0.21772  ,  0.52486  ,  0.63307  , -0.21206  ,
#        -1.6741   , -1.3811   ,  0.079469 ,  0.46871  ,  0.29956  ,
#        -0.90023  , -0.16781  , -0.30873  ,  0.16586  ,  0.12141  ,
#         0.50219  ,  0.049859 ,  0.54896  ,  0.55576  , -0.14683  ,
#         0.55657  , -0.0060587,  0.25941  , -0.91918  ,  0.23     ,
#        -0.32992  ,  0.18277  ,  0.036235 , -0.71589  ,  0.22084  ,
#         0.3952   , -0.46155  ,  1.0515   , -0.58014  , -0.19766  ,
#        -0.39474  , -1.2366   , -0.37599  ,  0.070743 ,  0.93192  ,
#        -0.31744  ,  0.26108  , -0.23069  , -0.1247   ,  0.81297  ,
#         0.56446  ,  0.043594 ,  0.69141  ,  0.3543   ,  0.60907  ],
#       dtype=float32)

# %%
wv.most_similar('cricket')
# Out:
# [('rugby', 0.7827098369598389),
#  ('twenty20', 0.7362942099571228),
#  ('england', 0.7173773646354675),
#  ('indies', 0.715782105922699),
#  ('cricketers', 0.7132172584533691),
#  ('football', 0.6659637093544006),
#  ('zealand', 0.6606222987174988),
#  ('matches', 0.6509107351303101),
#  ('bowling', 0.6504763960838318),
#  ('wc2003-wis', 0.642265260219574)]

# %%
wv.most_similar('happy')
# Out:
# [("'m", 0.8413287997245789),
#  ('feel', 0.8132575750350952),
#  ("'re", 0.8048083186149597),
#  ('i', 0.7938276529312134),
#  ("'ll", 0.7916273474693298),
#  ('really', 0.7903971076011658),
#  ('glad', 0.7833361029624939),
#  ('good', 0.7821646332740784),
#  ('we', 0.7808917164802551),
#  ('sure', 0.7788466215133667)]

# %%
wv.similarity("hockey", "sports")
# Out:
# 0.61933815

# %%
vec = wv['king'] - wv["man"] + wv["women"]

# %%
vec
# Out:
# array([ 0.13780999, -0.31693006, -0.502452  ,  1.0154101 , -0.14744718,
#         0.79945   , -0.99088997,  0.27473304, -1.17468   , -1.263679  ,
#         0.05625001, -0.30519003, -0.26187   ,  0.56635   , -0.617401  ,
#        -1.139032  , -0.494089  , -0.995551  , -1.14527   , -0.00825998,
#        -0.71497   , -1.03702   ,  1.1123    ,  1.2681019 , -0.17834002,
#        -0.25116703,  1.41917   , -1.48201   ,  1.17335   , -0.397709  ,
#         0.728463  ,  0.38424   ,  0.760954  , -0.05114001,  0.30534002,
#         0.32726002, -0.10284996,  1.70397   , -1.601243  ,  0.07513499,
#        -0.97814   ,  0.334166  , -0.84703   , -1.05203   , -0.306062  ,
#        -0.91162   , -0.09182498,  0.510078  ,  0.23192002, -0.82496   ,
#        -0.42551002,  0.19180298,  0.34305006,  0.40857995, -0.02853002,
#        -1.8389    ,  0.31365   , -0.07905903,  0.76307005, -0.16797   ,
#        -0.56675   , -0.16105002,  1.21367   ,  0.089894  ,  0.62215006,
#        -0.11048299, -0.79039   ,  0.44873005,  0.30726   , -0.602255  ,
#         0.26415   , -1.08699   , -0.23933   ,  0.51805997, -0.33482   ,
#         0.72651   , -0.23422   ,  0.90115005, -0.87257004, -0.38901997,
#         0.25972998, -0.60111   ,  0.756927  ,  0.711631  , -1.55971   ,
#         0.11065996, -0.51321995, -1.558355  ,  0.948378  , -0.25966197,
#         0.417619  , -0.43687996,  0.60485303,  0.16028501, -1.63985   ,
#        -0.801976  , -1.15757   ,  0.25825998,  0.96564204,  0.03552997],
#       dtype=float32)

# %%
wv.most_similar([vec])
# Out:
# [('women', 0.6757388114929199),
#  ('king', 0.6564599871635437),
#  ('queen', 0.6119859218597412),
#  ('crown', 0.5486535429954529),
#  ('monarch', 0.536250650882721),
#  ('kingdom', 0.5288199186325073),
#  ('emperor', 0.5264806747436523),
#  ('children', 0.5258975028991699),
#  ('throne', 0.5210835933685303),
#  ('commonwealth', 0.5139016509056091)]
